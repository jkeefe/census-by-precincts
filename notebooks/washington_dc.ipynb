# %%
import pandas as pd

# %% [markdown]
# ## Load in the "rosetta stone" file
#
# I made this file using QGIS, the open-source mapping software. I loaded in the US Census 2010 block-level shapefile for DC and the DC police boundaries shapefile [from here](https://opendata.dc.gov/datasets/police-service-areas?geometry=-77.997%2C38.707%2C-76.032%2C39.081). I then used the block centroids, provided by the census, to colect them within each zone. Since the centroids, by nature, are a "half a block" from the nearest street, this is more reliable than a polygon-in-polygon calculation.
#
# I'll write up my steps for that soonest.

# %%
rosetta_df = pd.read_csv('../data/washington_dc/rosetta.csv')

# %%
rosetta_df
# Out:
#               GEOID10  DISTRICT  PSA  NAME  POLDIST_ID  GIS_ID SECTOR
# 0     110010104001019         7  707   707           7   psa_4    7D2
# 1     110010073011041         7  707   707           7   psa_4    7D2
# 2     110010098031002         7  707   707           7   psa_4    7D2
# 3     110010098033004         7  707   707           7   psa_4    7D2
# 4     110010098071009         7  708   708           7   psa_1    7D3
# ...               ...       ...  ...   ...         ...     ...    ...
# 6502  110010015004013         2  201   201           2  psa_55    2D1
# 6503  110010015004005         2  201   201           2  psa_55    2D1
# 6504  110010015001012         2  201   201           2  psa_55    2D1
# 6505  110010013012013         2  203   203           2  psa_50    2D1
# 6506  110010001004004         2  206   206           2  psa_29    2D2
#
# [6507 rows x 7 columns]

# %% [markdown]
# ## Load in the population data

# %% [markdown]
# I downloaded the population files from [census.data.gov](https://census.data.gov). Here's the ["productDownload_2020-06-07T194243" zip file](https://s3.amazonaws.com/media.johnkeefe.net/census-by-precinct/productDownload_2020-06-07T194243.zip) I got from the census, which you'll need if you're running this part — along with your paths to the file instead of mine.

# %%
# census P3 by block
df_p3 = pd.read_csv('/Volumes/JK_Smarts_Data/precinct_project/DC/productDownload_2020-06-07T194243/DECENNIALSF12010.P3_data_with_overlays_2020-06-07T194221.csv')

# %%
df_p3.reset_index(inplace=True)

# %%
df_p3.drop(0, inplace=True) #drops second column headers

# %%
# census P5 by block
df_p5 = pd.read_csv('/Volumes/JK_Smarts_Data/precinct_project/DC/productDownload_2020-06-07T194243/DECENNIALSF12010.P5_data_with_overlays_2020-06-07T194221.csv')

# %%
df_p5.reset_index(inplace=True)
df_p5.drop(0, inplace=True)

# %%
df_p3.shape, df_p5.shape
# Out:
# ((6507, 11), (6507, 20))

# %%
main_df = df_p3.merge(df_p5, on='GEO_ID')

# %%
main_df.shape
# Out:
# (6507, 30)

# %%
main_df
# Out:
#       index_x                    GEO_ID  \
# 0           1  1000000US110010040021000
# 1           2  1000000US110010040021001
# 2           3  1000000US110010040022000
# 3           4  1000000US110010040022001
# 4           5  1000000US110010040022003
# ...       ...                       ...
# 6502     6503  1000000US110010102001005
# 6503     6504  1000000US110010106003004
# 6504     6505  1000000US110010089032001
# 6505     6506  1000000US110010095052004
# 6506     6507  1000000US110010068022015
#
#                                                  NAME_x P003001 P003002  \
# 0     Block 1000, Block Group 1, Census Tract 40.02,...     273     199
# 1     Block 1001, Block Group 1, Census Tract 40.02,...     407     346
# 2     Block 2000, Block Group 2, Census Tract 40.02,...     464     377
# 3     Block 2001, Block Group 2, Census Tract 40.02,...     345     298
# 4     Block 2003, Block Group 2, Census Tract 40.02,...     315     239
# ...                                                 ...     ...     ...
# 6502  Block 1005, Block Group 1, Census Tract 102, D...       0       0
# 6503  Block 3004, Block Group 3, Census Tract 106, D...     130      46
# 6504  Block 2001, Block Group 2, Census Tract 89.03,...     193      10
# 6505  Block 2004, Block Group 2, Census Tract 95.05,...      52       2
# 6506  Block 2015, Block Group 2, Census Tract 68.02,...     115      65
#
#      P003003 P003004 P003005 P003006 P003007  ... P005008  P005009 P005010  \
# 0         24       0      10       1      22  ...       0       11      57
# 1         27       1      17       0       9  ...       1        7      45
# 2         39       0      30       0       9  ...       0        8      34
# 3         26       0       7       0       2  ...       0       11      20
# 4         24       1      35       0       9  ...       0        7      27
# ...      ...     ...     ...     ...     ...  ...     ...      ...     ...
# 6502       0       0       0       0       0  ...       0        0       0
# 6503      84       0       0       0       0  ...       0        0       0
# 6504     175       0       0       0       0  ...       0        8       3
# 6505      49       0       0       0       0  ...       0        1       1
# 6506      39       0       7       0       1  ...       0        3       6
#
#      P005011 P005012 P005013 P005014 P005015 P005016 P005017
# 0         17      12       0       0       0      22       6
# 1         33       4       0       0       0       8       0
# 2         22       0       0       2       0       9       1
# 3         16       1       0       0       0       2       1
# 4         18       0       0       0       0       9       0
# ...      ...     ...     ...     ...     ...     ...     ...
# 6502       0       0       0       0       0       0       0
# 6503       0       0       0       0       0       0       0
# 6504       2       1       0       0       0       0       0
# 6505       0       1       0       0       0       0       0
# 6506       4       1       0       0       0       1       0
#
# [6507 rows x 30 columns]

# %%
main_df.columns
# Out:
# Index(['index_x', 'GEO_ID', 'NAME_x', 'P003001', 'P003002', 'P003003',
#        'P003004', 'P003005', 'P003006', 'P003007', 'P003008', 'index_y',
#        'NAME_y', 'P005001', 'P005002', 'P005003', 'P005004', 'P005005',
#        'P005006', 'P005007', 'P005008', 'P005009', 'P005010', 'P005011',
#        'P005012', 'P005013', 'P005014', 'P005015', 'P005016', 'P005017'],
#       dtype='object')

# %%
main_df['GEOID10'] = main_df['GEO_ID'].str[9:].astype(int)

# %%
main_df.drop(columns=['index_x'], inplace = True)

# %%
main_df.drop(columns=['index_y', 'NAME_y'], inplace = True)

# %%
main_df.columns
# Out:
# Index(['GEO_ID', 'NAME_x', 'P003001', 'P003002', 'P003003', 'P003004',
#        'P003005', 'P003006', 'P003007', 'P003008', 'P005001', 'P005002',
#        'P005003', 'P005004', 'P005005', 'P005006', 'P005007', 'P005008',
#        'P005009', 'P005010', 'P005011', 'P005012', 'P005013', 'P005014',
#        'P005015', 'P005016', 'P005017', 'GEOID10'],
#       dtype='object')

# %%
rosetta_df.shape
# Out:
# (6507, 7)

# %%
rosetta_df.dtypes
# Out:
# GEOID10        int64
# DISTRICT       int64
# PSA            int64
# NAME           int64
# POLDIST_ID     int64
# GIS_ID        object
# SECTOR        object
# dtype: object

# %%
main_df.dtypes
# Out:
# GEO_ID     object
# NAME_x     object
# P003001    object
# P003002    object
# P003003    object
# P003004    object
# P003005    object
# P003006    object
# P003007    object
# P003008    object
# index_y     int64
# NAME_y     object
# P005001    object
# P005002    object
# P005003    object
# P005004    object
# P005005    object
# P005006    object
# P005007    object
# P005008    object
# P005009    object
# P005010    object
# P005011    object
# P005012    object
# P005013    object
# P005014    object
# P005015    object
# P005016    object
# P005017    object
# GEOID10     int64
# dtype: object

# %%
# need to make all those columns numeric
main_df[['P003001', 'P003002', 'P003003', 'P003004',
       'P003005', 'P003006', 'P003007', 'P003008', 'P005001', 'P005002',
       'P005003', 'P005004', 'P005005', 'P005006', 'P005007', 'P005008',
       'P005009', 'P005010', 'P005011', 'P005012', 'P005013', 'P005014',
       'P005015', 'P005016', 'P005017']] = main_df[['P003001', 'P003002', 'P003003', 'P003004',
       'P003005', 'P003006', 'P003007', 'P003008', 'P005001', 'P005002',
       'P005003', 'P005004', 'P005005', 'P005006', 'P005007', 'P005008',
       'P005009', 'P005010', 'P005011', 'P005012', 'P005013', 'P005014',
       'P005015', 'P005016', 'P005017']].apply(pd.to_numeric)

# %%
## Add districts to every block's demo data
block_data = main_df.merge(rosetta_df, on="GEOID10", how="left")

# %%
block_data.shape
# Out:
# (6507, 34)

# %%
block_data
# Out:
#                         GEO_ID  \
# 0     1000000US110010040021000
# 1     1000000US110010040021001
# 2     1000000US110010040022000
# 3     1000000US110010040022001
# 4     1000000US110010040022003
# ...                        ...
# 6502  1000000US110010102001005
# 6503  1000000US110010106003004
# 6504  1000000US110010089032001
# 6505  1000000US110010095052004
# 6506  1000000US110010068022015
#
#                                                  NAME_x  P003001  P003002  \
# 0     Block 1000, Block Group 1, Census Tract 40.02,...      273      199
# 1     Block 1001, Block Group 1, Census Tract 40.02,...      407      346
# 2     Block 2000, Block Group 2, Census Tract 40.02,...      464      377
# 3     Block 2001, Block Group 2, Census Tract 40.02,...      345      298
# 4     Block 2003, Block Group 2, Census Tract 40.02,...      315      239
# ...                                                 ...      ...      ...
# 6502  Block 1005, Block Group 1, Census Tract 102, D...        0        0
# 6503  Block 3004, Block Group 3, Census Tract 106, D...      130       46
# 6504  Block 2001, Block Group 2, Census Tract 89.03,...      193       10
# 6505  Block 2004, Block Group 2, Census Tract 95.05,...       52        2
# 6506  Block 2015, Block Group 2, Census Tract 68.02,...      115       65
#
#       P003003  P003004  P003005  P003006  P003007  P003008  ...  P005015  \
# 0          24        0       10        1       22       17  ...        0
# 1          27        1       17        0        9        7  ...        0
# 2          39        0       30        0        9        9  ...        0
# 3          26        0        7        0        2       12  ...        0
# 4          24        1       35        0        9        7  ...        0
# ...       ...      ...      ...      ...      ...      ...  ...      ...
# 6502        0        0        0        0        0        0  ...        0
# 6503       84        0        0        0        0        0  ...        0
# 6504      175        0        0        0        0        8  ...        0
# 6505       49        0        0        0        0        1  ...        0
# 6506       39        0        7        0        1        3  ...        0
#
#       P005016  P005017          GEOID10  DISTRICT  PSA  NAME  POLDIST_ID  \
# 0          22        6  110010040021000         3  303   303           3
# 1           8        0  110010040021001         3  303   303           3
# 2           9        1  110010040022000         3  303   303           3
# 3           2        1  110010040022001         3  303   303           3
# 4           9        0  110010040022003         3  303   303           3
# ...       ...      ...              ...       ...  ...   ...         ...
# 6502        0        0  110010102001005         1  103   103           1
# 6503        0        0  110010106003004         5  501   501           5
# 6504        0        0  110010089032001         5  507   507           5
# 6505        0        0  110010095052004         4  406   406           4
# 6506        1        0  110010068022015         1  107   107           1
#
#       GIS_ID  SECTOR
# 0     psa_37     3D3
# 1     psa_37     3D3
# 2     psa_37     3D3
# 3     psa_37     3D3
# 4     psa_37     3D3
# ...      ...     ...
# 6502  psa_12     1D1
# 6503  psa_35     5D1
# 6504  psa_23     5D3
# 6505  psa_54     4D2
# 6506  psa_16     1D2
#
# [6507 rows x 34 columns]

# %%
block_data.to_csv('./temp_data/dc_2010blocks_2020policedistricts_population.csv', index=False)

# %%
## Check for duplicates
block_data.duplicated(subset='GEOID10', keep='first').sum()
# Out:
# 0

# %%
import numpy as np
pivot = pd.pivot_table(block_data, index="DISTRICT", aggfunc=np.sum)

# %%
pivot
# Out:
#                      GEOID10    NAME  P003001  P003002  P003003  P003004  \
# DISTRICT
# 1         113200366788363744  107915    70188    36738    26788      282
# 2         186026955156884448  346078   140138   115011     8013      294
# 3          56325140613156680  156028    95326    48393    30854      432
# 4         117490722860241392  431694   100226    20443    62398      475
# 5          81407470139746432  372868    55839     7106    45006      236
# 6          93728591642625552  515051    74065     1284    70447      222
# 7          67656202377240896  433643    65941     2496    61619      138
#
#           P003005  P003006  P003007  P003008  ...  P005010  P005011  P005012  \
# DISTRICT                                      ...
# 1            3364       40      980     1996  ...     3493     1828      402
# 2           10393       71     2125     4231  ...    10208     7402      254
# 3            4570       67     7410     3600  ...    15386     5959      803
# 4            1695       73    11391     3751  ...    19677     5310     1198
# 5             648       18     1417     1408  ...     3120      898      482
# 6             147       13      714     1238  ...     1624      279      489
# 7             239       20      337     1092  ...     1241      331      444
#
#           P005013  P005014  P005015  P005016  P005017  POLDIST_ID     PSA
# DISTRICT
# 1              43       36        1      816      367        1029  107915
# 2             114       85       22     1686      645        3382  346078
# 3             219       55       27     7114     1209        1536  156028
# 4             253       34       32    11080     1770        4272  431694
# 5              77       18        2     1321      322        3700  372868
# 6              30        0        2      639      185        5112  515051
# 7              21       10        0      267      168        4305  433643
#
# [7 rows x 29 columns]

# %%
pivot.reset_index(inplace=True)

# %%
# drop columns whose sums make no sense
pivot.drop(columns=['GEOID10','POLDIST_ID','PSA'], inplace=True)

# %%
pivot.drop(columns=['NAME'], inplace=True)

# %%
pivot.columns
# Out:
# Index(['DISTRICT', 'P003001', 'P003002', 'P003003', 'P003004', 'P003005',
#        'P003006', 'P003007', 'P003008', 'P005001', 'P005002', 'P005003',
#        'P005004', 'P005005', 'P005006', 'P005007', 'P005008', 'P005009',
#        'P005010', 'P005011', 'P005012', 'P005013', 'P005014', 'P005015',
#        'P005016', 'P005017'],
#       dtype='object')

# %%
pivot
# Out:
#    DISTRICT  P003001  P003002  P003003  P003004  P003005  P003006  P003007  \
# 0         1    70188    36738    26788      282     3364       40      980
# 1         2   140138   115011     8013      294    10393       71     2125
# 2         3    95326    48393    30854      432     4570       67     7410
# 3         4   100226    20443    62398      475     1695       73    11391
# 4         5    55839     7106    45006      236      648       18     1417
# 5         6    74065     1284    70447      222      147       13      714
# 6         7    65941     2496    61619      138      239       20      337
#
#    P003008  P005001  ...  P005008  P005009  P005010  P005011  P005012  \
# 0     1996    70188  ...      164     1629     3493     1828      402
# 1     4231   140138  ...      439     3586    10208     7402      254
# 2     3600    95326  ...      296     2391    15386     5959      803
# 3     3751   100226  ...      311     1981    19677     5310     1198
# 4     1408    55839  ...       96     1086     3120      898      482
# 5     1238    74065  ...       75     1053     1624      279      489
# 6     1092    65941  ...       70      924     1241      331      444
#
#    P005013  P005014  P005015  P005016  P005017
# 0       43       36        1      816      367
# 1      114       85       22     1686      645
# 2      219       55       27     7114     1209
# 3      253       34       32    11080     1770
# 4       77       18        2     1321      322
# 5       30        0        2      639      185
# 6       21       10        0      267      168
#
# [7 rows x 26 columns]

# %%
pivot.to_csv('../data/washington_dc/dc_2010pop_by_2020police_districts.csv', index=False)

# %%
pivot['P003001'].sum()
# Out:
# 601723

# %%
pivot_psa = pd.pivot_table(block_data, index="PSA", aggfunc=np.sum)

# %%
pivot_psa.reset_index(inplace=True)

# %%
pivot_psa.columns
# Out:
# Index(['PSA', 'DISTRICT', 'GEOID10', 'NAME', 'P003001', 'P003002', 'P003003',
#        'P003004', 'P003005', 'P003006', 'P003007', 'P003008', 'P005001',
#        'P005002', 'P005003', 'P005004', 'P005005', 'P005006', 'P005007',
#        'P005008', 'P005009', 'P005010', 'P005011', 'P005012', 'P005013',
#        'P005014', 'P005015', 'P005016', 'P005017', 'POLDIST_ID'],
#       dtype='object')

# %%
pivot_psa
# Out:
#     PSA  DISTRICT            GEOID10    NAME  P003001  P003002  P003003  \
# 0   101        64   7040643468491659    6464     6407     3259     1469
# 1   102       132  14521328766612804   13464     4864     1275     3218
# 2   103       164  18041654668384396   16892     5972     2915     2348
# 3   104        79   8690796693785585    8216     8890     4825     3421
# 4   105        75   8250756085154956    7875     5620     1096     4030
# 5   106       237  26072386606591036   25122    11181     6968     3349
# 6   107       142  15621429615360044   15194    15433     7946     6462
# 7   108       136  14961370883983136   14688    11821     8454     2491
# 8   201       402  22112012823552976   40401    14205    11678     1274
# 9   202       470  25852352488216800   47470    11906    10077      534
# 10  203       292  16061461693342012   29638    17655    14260     1181
# 11  204       394  21671971453982488   40188    24174    20403      979
# 12  205       470  25852351983784008   48175    18910    16130      771
# 13  206       376  20681880956945452   38728    16466    14050      569
# 14  207       576  31682901304966968   59616    17101    13400     1005
# 15  208       294  16171478396938106   30576    17738    13612     1401
# 16  209       108   5940544055155298   11286     1983     1401      299
# 17  301       150   5500502284488141   15050    11073     8019     1585
# 18  302       240   8800802250135362   24160    19150     9850     4762
# 19  303       207   7590692675567223   20907    15621    11631     1753
# 20  304       111   4070371325068100   11248    12506     4353     5667
# 21  305       132   4840441882069375   13420     6173     3073     2404
# 22  306       183   6710612141342439   18666     7834     1635     5524
# 23  307       273  10010914515538416   27937    12753     6607     3523
# 24  308       240   8800803538947718   24640    10216     3225     5636
# 25  401       764  21011917035675048   76591    10869     2843     6701
# 26  402       496  13641242330893910   49848    11721     1267     8268
# 27  403       480  13201202507982576   48360    13462     2123     8428
# 28  404       496  13641243002590306   50096    11835     3269     5661
# 29  405       644  17711623141574276   65205    15766     3994    10312
# 30  406       560  15401409610742028   56840     9600      684     8107
# 31  407       580  15951453321525932   59015    13121     1984     8938
# 32  408       112   3080280799186085   11424     7815     2834     2610
# 33  409       140   3850351110071129   14315     6037     1445     3373
# 34  501       340   7480686875787155   34068     4144     1685     2087
# 35  502       465  10230938337032526   46686    11121     1792     8366
# 36  503      1020  22442060890592256  102612     9991      679     8598
# 48       21       20        0  ...      105      180       31       38
# 49       15       11        0  ...      100       63        9       18
# 50       12       11        0  ...       81       80        9       51
# 51       23       36        3  ...       73      187       32       76
# 52       10       20        0  ...      118      122       18       55
# 53       15       10        0  ...       57      108       46       31
# 54       19       15        6  ...       97      103       14       54
# 55       27       82        2  ...      229      346      130       78
# 56       17       54        9  ...      169      232       73       81
#
#     P005013  P005014  P005015  P005016  P005017  POLDIST_ID
# 0         1        3        0      141       43          64
# 1         5        4        0       36       18         132
# 2         5        4        0       66       51         164
# 3         2       10        0       94       34          79
# 4         5        0        0       89       23          75
# 5         4        3        0       90       68         237
# 6        10        4        1      168       85         142
# 7        11        8        0      132       45         136
# 8         7        5        2      144       68         402
# 9        17        7        1       99       48         470
# 10       15       14        0      213       73         292
# 11       33       18        0      341      132         394
# 12        8        6        0      183       87         470
# 13        6       11        0      120       65         376
# 14        3        7        1      152       56         576
# 15       25       13       18      397      109         294
# 16        0        4        0       37        7         108
# 17       18       13        0      402       63         150
# 18       94       14        5     2601      449         240
# 19       22        7        6      726      152         207
# 20       27        9        3     1422      270         111
# 21        6        1        0      146       29         132
# 22       13        7        1      121       38         183
# 23       29        2        6     1409      151         273
# 24       10        2        6      287       57         240
# 25       28        3        1      560      102         764
# 26       33        7        0     1527      187         496
# 27       29        7       15     2045      305         480
# 28       31        2        3     1823      457         496
# 29       23        6        5      660      113         644
# 30       13        1        4      444       84         560
# 31       47        0        3     1517      165         580
# 32       38        4        1     1592      272         112
# 33       11        4        0      912       85         140
# 34       13        1        0       75       17         340
# 35       21       10        1      445       83         465
# 36        6        1        0      259       69        1020
# 37       13        4        0      164       56         695
# 38        5        0        0      108       30         330
# 39       13        1        0      138       28         370
# 40        6        1        1      132       39         480
# 41        3        0        0       40        6         450
# 42        1        0        1      138       19         852
# 43        5        0        0      159       45         594
# 44        6        0        0      142       42         612
# 45        3        0        0       38       16         858
# 46        3        0        1       32        8         414
# 47        3        0        0       16       18         708
# 48        6        0        0       74       31         624
# 49        6        0        0       22        8         385
# 50        0        0        0        3       17         259
# 51        4        1        0       46       28         847
# 52        4        1        0       30       14         385
# 53        1        0        0       20       10         336
# 54        2        1        0       13       19         322
# 55        3        5        0       89       41         763
# 56        1        2        0       44       31        1008
#
# [57 rows x 30 columns]

# %%
# drop columns whose sums make no sense
pivot_psa.drop(columns=['DISTRICT', 'GEOID10', 'NAME', 'POLDIST_ID'], inplace=True)

# %%
pivot_psa
# Out:
#     PSA  P003001  P003002  P003003  P003004  P003005  P003006  P003007  \
# 0   101     6407     3259     1469       18     1331        4      149
# 1   102     4864     1275     3218       14      200        3       44
# 2   103     5972     2915     2348       25      366        3       82
# 3   104     8890     4825     3421       21      230       11      115
# 4   105     5620     1096     4030       51      161        3      107
# 5   106    11181     6968     3349       40      388        7      120
# 6   107    15433     7946     6462       67      341        4      206
# 7   108    11821     8454     2491       46      347        5      157
# 8   201    14205    11678     1274       18      637        6      190
# 9   202    11906    10077      534       34      683        7      142
# 10  203    17655    14260     1181       38     1388        4      266
# 11  204    24174    20403      979       66     1605        6      430
# 12  205    18910    16130      771       29     1147        7      250
# 13  206    16466    14050      569       23     1206       11      157
# 26      407    11721  ...       37      220     2499      617      128
# 27      526    13462  ...       48      221     3457      837      219
# 28      735    11835  ...       68      278     3428      918      194
# 29      434    15766  ...       33      321     1304      381      116
# 30      257     9600  ...       11      173      804      176       82
# 31      398    13121  ...       27      233     2558      652      174
# 32      413     7815  ...       30      141     2870      895       68
# 33      146     6037  ...       13       61     1578      477       89
# 34      135     4144  ...        9      118      260      118       36
# 35      277    11121  ...       29      194      887      211      116
# 36      282     9991  ...       18      213      562      142       85
# 37      264     6588  ...        4      208      510      205       68
# 38       87     5068  ...       16       57      224       37       44
# 39      144     7389  ...        4      116      339       84       75
# 40      219    11538  ...       16      180      338      101       58
# 41       79     5574  ...        1       73       75       14       12
# 42      159     9647  ...       10      140      280       40       81
# 43      230    12959  ...        9      185      328       41       78
# 44      242    13174  ...       10      200      353       51      112
# 45      122     8924  ...       13      106      156       35       64
# 46      100     5961  ...        8       92      112       32       36
# 47      170     9529  ...        6      152      140       35       68
# 48      136     8297  ...       18      105      180       31       38
# 49      108     6371  ...        4      100       63        9       18
# 50       98     6840  ...       11       81       80        9       51
# 51      101     8549  ...        7       73      187       32       76
# 52      132     9794  ...       10      118      122       18       55
# 53       67     5713  ...        4       57      108       46       31
# 54      116     9494  ...        9       97      103       14       54
# 55      270     8280  ...        6      229      346      130       78
# 56      200    10900  ...       19      169      232       73       81
#
#     P005013  P005014  P005015  P005016  P005017
# 0         1        3        0      141       43
# 1         5        4        0       36       18
# 2         5        4        0       66       51
# 3         2       10        0       94       34
# 4         5        0        0       89       23
# 5         4        3        0       90       68
# 6        10        4        1      168       85
# 7        11        8        0      132       45
# 8         7        5        2      144       68
# 9        17        7        1       99       48
# 10       15       14        0      213       73
# 11       33       18        0      341      132
# 12        8        6        0      183       87
# 13        6       11        0      120       65
# 14        3        7        1      152       56
# 15       25       13       18      397      109
# 16        0        4        0       37        7
# 17       18       13        0      402       63
# 18       94       14        5     2601      449
# 19       22        7        6      726      152
# 20       27        9        3     1422      270
# 21        6        1        0      146       29
# 22       13        7        1      121       38
# 23       29        2        6     1409      151
# 24       10        2        6      287       57
# 25       28        3        1      560      102
# 26       33        7        0     1527      187
# 27       29        7       15     2045      305
# 28       31        2        3     1823      457
# 29       23        6        5      660      113
# 30       13        1        4      444       84
# 31       47        0        3     1517      165
# 32       38        4        1     1592      272
# 33       11        4        0      912       85
# 34       13        1        0       75       17
# 35       21       10        1      445       83
# 36        6        1        0      259       69
# 37       13        4        0      164       56
# 38        5        0        0      108       30
# 39       13        1        0      138       28
# 40        6        1        1      132       39
# 41        3        0        0       40        6
# 42        1        0        1      138       19
# 43        5        0        0      159       45
# 44        6        0        0      142       42
# 45        3        0        0       38       16
# 46        3        0        1       32        8
# 47        3        0        0       16       18
# 48        6        0        0       74       31
# 49        6        0        0       22        8
# 50        0        0        0        3       17
# 51        4        1        0       46       28
# 52        4        1        0       30       14
# 53        1        0        0       20       10
# 54        2        1        0       13       19
# 55        3        5        0       89       41
# 56        1        2        0       44       31
#
# [57 rows x 26 columns]

# %%
pivot_psa.to_csv('../data/washington_dc/dc_2010pop_by_2020public_service_area.csv', index=False)

# %% [markdown]
# Done!
